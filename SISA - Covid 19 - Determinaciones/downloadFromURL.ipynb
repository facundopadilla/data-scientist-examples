# %%
import pandas as pd
import urllib3 as url3

def downloadFromURL(url, decode = "utf-8", sep = ",", sep_columnas = ",", del_comillas = False, del_n = False, del_r = False):
    try:
        http = url3.PoolManager() # crear el pool manager
        r = http.request('GET', url) # obtener datos por metodo get
        print("Estado de conexión:", r.status) # mostrar el estado de conexión, si es 200 es aceptable
        datos = (r.data).decode(decode).strip() # guardo los datos decodificados y sin espacios
        if del_comillas == True:
            datos = datos.replace('"',"") # elimino las comillas dobles
        if del_n == True:
            datos = datos.replace('\n',"") # elimino los saltos de linea
        if del_r == True:
            datos = datos.replace('\r',"") # elimino los \r que no se que son
        datos = datos.split(sep) # separo los datos 
        columnas = datos[0].split(sep_columnas) # separo las columnas
        main_dict = {columna:[] for columna in columnas}
        [main_dict[columnas[i]].append(datos[linea].strip().split(sep_columnas)[i]) for linea in range(1, len(datos)) for i in range(0, len(columnas))]
        df = pd.DataFrame(main_dict)
        df['positivos'] = df['positivos'].replace("","0")
        return df
    except UnicodeDecodeError:
        print(">>> Error: no se puede decodificar con UTF-8 por defecto, utilice 'utf-16' u otro decodificador.")

# %%
covid_df = downloadFromURL('https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Determinaciones.csv',
                          'utf-16',
                          del_comillas = True,
                           sep = '\r',
                           del_n = True
                          )
covid_df.head(10)
# Out:
# Estado de conexión: 200
#         fecha     provincia codigo_indec_provincia  departamento  \
# 0  2020-02-11          CABA                     02      COMUNA 4
# 1  2020-02-20          CABA                     02      COMUNA 4
# 2  2020-02-20  Buenos Aires                     06  Bahía Blanca
# 3  2020-02-27          CABA                     02      COMUNA 4
# 4  2020-02-28          CABA                     02      COMUNA 4
# 5  2020-03-02          CABA                     02      COMUNA 4
# 6  2020-03-03          CABA                     02      COMUNA 4
# 7  2020-03-04          CABA                     02      COMUNA 4
# 8  2020-03-05          CABA                     02      COMUNA 4
# 9  2020-03-06          CABA                     02      COMUNA 4
#
#   codigo_indec_departamento         localidad codigo_indec_localidad  \
# 0                       004  PARQUE PATRICIOS                    010
# 1                       004  PARQUE PATRICIOS                    010
# 2                       056      BAHIA BLANCA                    010
# 3                       004  PARQUE PATRICIOS                    010
# 4                       004  PARQUE PATRICIOS                    010
# 5                       004  PARQUE PATRICIOS                    010
# 6                       004  PARQUE PATRICIOS                    010
# 7                       004  PARQUE PATRICIOS                    010
# 8                       004  PARQUE PATRICIOS                    010
# 9                       004  PARQUE PATRICIOS                    010
#
#   origen_de_financiamiento      tipo ultima_actualizacion total positivos
# 0                  Público  Nacional           2020-06-26     2         0
# 1                  Público  Nacional           2020-06-26     1         0
# 2                  Privado   Privado           2020-06-26     1         0
# 3                  Público  Nacional           2020-06-26     4         0
# 4                  Público  Nacional           2020-06-26    10         0
# 5                  Público  Nacional           2020-06-26     5         0
# 6                  Público  Nacional           2020-06-26     8         1
# 7                  Público  Nacional           2020-06-26     6         0
# 8                  Público  Nacional           2020-06-26     7         0
# 9                  Público  Nacional           2020-06-26    11         7
